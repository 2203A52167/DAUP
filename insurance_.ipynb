# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/insurance.csv')
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
#create vectors
#vector is column which contains the numerical or continous values
vector1 = data['age'].values
vector2 = data['bmi'].values
print(vector1)
print(vector2)
# Out:
# [19 18 28 ... 18 21 61]
# [27.9 33.8 33.  ... 36.9 25.8 29.1]

# %%
#create factor
#factor is a row or a column which contains the categorial values
factor1 = data['smoker'].values
factor2 = data['region'].values
print(factor1)
print(factor2)
# Out:
# ['yes' 'no' 'no' ... 'no' 'no' 'yes']
# ['southwest' 'southeast' 'southeast' ... 'southeast' 'southwest'
#  'northwest']

# %%
#count the amount of teenage smokers
teenagers = data[(data['age']>=13)&(data['age']<=19)] #we will get the total data by filtering the age condition
teenagers_smokers = teenagers[teenagers['smoker']=='yes']
no = teenagers_smokers.shape[0]
print(f"number of teenager smokers: {no}")
#teenage_smoker_count = data['smoker']
#teenage_smoker_count = data['smoker']
# Out:
# number of teenager smokers: 30

# %%
#list - list can store the values of different data types.
list1= data[['age','smoker','region']].values.tolist()
print(list1)
# Out:
# [[19, 'yes', 'southwest'], [18, 'no', 'southeast'], [28, 'no', 'southeast'], [33, 'no', 'northwest'], [32, 'no', 'northwest'], [31, 'no', 'southeast'], [46, 'no', 'southeast'], [37, 'no', 'northwest'], [37, 'no', 'northeast'], [60, 'no', 'northwest'], [25, 'no', 'northeast'], [62, 'yes', 'southeast'], [23, 'no', 'southwest'], [56, 'no', 'southeast'], [27, 'yes', 'southeast'], [19, 'no', 'southwest'], [52, 'no', 'northeast'], [23, 'no', 'northeast'], [56, 'no', 'southwest'], [30, 'yes', 'southwest'], [60, 'no', 'northeast'], [30, 'no', 'southwest'], [18, 'no', 'southeast'], [34, 'yes', 'northeast'], [37, 'no', 'northwest'], [59, 'no', 'southeast'], [63, 'no', 'northeast'], [55, 'no', 'northwest'], [23, 'no', 'northwest'], [31, 'yes', 'southwest'], [22, 'yes', 'southwest'], [18, 'no', 'northeast'], [19, 'no', 'southwest'], [63, 'no', 'northwest'], [28, 'yes', 'southwest'], [19, 'no', 'northwest'], [62, 'no', 'northwest'], [26, 'no', 'southwest'], [35, 'yes', 'northeast'], [60, 'yes', '
# ...

# %%
#matrix
matrix1 = data[['age','bmi']].values
print(matrix1)
# Out:
# [[19.  27.9]
#  [18.  33.8]
#  [28.  33. ]
#  ...
#  [18.  36.9]
#  [21.  25.8]
#  [61.  29.1]]

# %%
#dataframe
dataframe1 = data[['age','sex','bmi']].values
print(dataframe1)
# Out:
# [[19 'female' 27.9]
#  [18 'male' 33.8]
#  [28 'male' 33.0]
#  ...
#  [18 'female' 36.9]
#  [21 'female' 25.8]
#  [61 'female' 29.1]]

# %%
# !pip install matplotlib

import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame and 'age', 'bmi' are the columns you want to plot
# Extract the data for the scatter plot
age = data['age']
bmi = data['bmi']

# Create the scatter plot
plt.scatter(age, bmi, marker='+', color='blue')  # Change marker to '+'

# Customize the plot
plt.title('Scatter Plot of Age vs. BMI')
plt.xlabel('Age')
plt.ylabel('BMI')

# Add text annotation (example)
plt.text(30, 35, 'Example Annotation', fontsize=12, color='red')

# Show the plot
plt.show()

# %%
# 2. Now you can use 'data' in the following code:
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.scatter(data['age'], data['smoker'], marker='o', color='blue')
plt.title('Scatter Plot of Age vs. Smoking')
plt.xlabel('Age')
plt.ylabel('Smoker (yes/no)')
plt.show()

# %%
# 3. Scatter plot between age (20 to 40) and smoking
filtered_data = data[(data['age'] >= 20) & (data['age'] <= 40)]
plt.figure(figsize=(8, 6))
plt.scatter(filtered_data['age'], filtered_data['smoker'], marker='o', color='green')
plt.title('Scatter Plot of Age (20-40) vs. Smoking')
plt.xlabel('Age')
plt.ylabel('Smoker (yes/no)')
plt.show()

# %%
# 4. Expenses of smokers and non-smokers
smoker_expenses = data[data['smoker'] == 'yes']['expenses'].mean()
nonsmoker_expenses = data[data['smoker'] == 'no']['expenses'].mean()

plt.figure(figsize=(6, 4))
plt.bar(['Smoker', 'Non-smoker'], [smoker_expenses, nonsmoker_expenses], color=['red', 'blue'])
plt.title('Average Expenses of Smokers vs. Non-smokers')
plt.ylabel('Average Expenses')
plt.show()

# %%
# 5. Number of smokers gender-wise
smoker_gender_counts = data[data['smoker'] == 'yes']['sex'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(smoker_gender_counts.index, smoker_gender_counts.values, color=['pink', 'lightblue'])
plt.title('Number of Smokers by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Smokers')
plt.show()

# %%
# 6. Scatter plot between age and expenses
plt.figure(figsize=(8, 6))
plt.scatter(data['age'], data['expenses'], marker='o', color='purple')
plt.title('Scatter Plot of Age vs. Expenses')
plt.xlabel('Age')
plt.ylabel('Expenses')
plt.show()
